# %%
import torch
import cvxpy as cp
import numpy as np
from cvxpylayers.torch import CvxpyLayer
from scipy.linalg import sqrtm
from scipy.linalg import solve_discrete_are

torch.set_default_dtype(torch.double)

cuda0 = torch.device('cuda:0')
cpu = torch.device('cpu')
device = cuda0

torch.set_printoptions(precision=3)
torch.set_printoptions(sci_mode=False)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
print(torch.cuda.current_device())
torch.cuda.set_device(0)
# Out:
# True
# 1
# NVIDIA RTX A2000 Laptop GPU
# 11.6
# 0

# %%
np.random.seed(1)

# generate problem data
n, m = 8, 2
noise = np.sqrt(.25)
u_max = .1
Q0 = np.eye(n)
R0 = np.eye(m)
A = np.random.randn(n, n)
A /= np.max(np.abs(np.linalg.eig(A)[0]))
B = np.random.randn(n, m)
W = noise**2 * np.eye(n)

# %%
# compute unconstrained lqr solution
P = cp.Variable((n, n), PSD=True)
R0cvxpy = cp.Parameter((m, m), PSD=True)

objective = cp.trace(P@W)
constraints = [cp.bmat([
    [R0cvxpy + B.T@P@B, B.T@P@A],
    [A.T@P@B, Q0+A.T@P@A-P]
]) >> 0, P >> 0]
R0cvxpy.value = R0
J_unconstrained_opt = cp.Problem(
    cp.Maximize(objective),
    constraints).solve()
P_unconstrained_opt = P.value
print("J_unconstrained_opt", J_unconstrained_opt)
# Out:
# J_unconstrained_opt 6.037566322322649

# %%
P_are = solve_discrete_are(A, B, Q0, R0)
np.testing.assert_allclose(P_are, P_unconstrained_opt, atol=1e-3)

# %%
# compute lower bound
P = cp.Variable((n, n), PSD=True)
R = cp.Variable((m, m), PSD=True)
lam = cp.Variable(m, nonneg=True)

objective = cp.trace(P@W) - (u_max**2)*cp.sum(lam)
constraints = [R - R0 << cp.diag(lam), P >> 0, R >> 0, lam >= 0]
constraints += [cp.bmat([
    [R + B.T@P@B, B.T@P@A],
    [A.T@P@B, Q0 + A.T@P@A-P]
]) >> 0]

j_lq_opt = cp.Problem(cp.Maximize(objective), constraints).solve()
print("lower bound j_lq_opt", j_lq_opt)

P_lq_opt = P.value
K_lq_opt = -np.linalg.solve(R0 + B.T @ P_lq_opt @ B, B.T @ P_lq_opt @ A)
# Out:
# lower bound j_lq_opt 10.702688100154873

# %%
Qt, Rt, At, Bt = map(torch.from_numpy, [Q0, R0, A, B])

Qt = Qt.to(device)
Rt = Rt.to(device)
At = At.to(device)
Bt = Bt.to(device)

def lb_loss(time_horizon, batch_size, K, seed=None):
    ''' Monte-Carlo \hat{J} for DARE-solution-based K: u = K x'''
    if seed is not None:
        torch.manual_seed(seed)
    x_batch = noise * torch.randn(batch_size, n, 1).double()
    K_batch = K.repeat(batch_size, 1, 1)
    Qt_batch = Qt.repeat(batch_size, 1, 1)
    Rt_batch = Rt.repeat(batch_size, 1, 1)
    At_batch = At.repeat(batch_size, 1, 1)
    Bt_batch = Bt.repeat(batch_size, 1, 1)
    
    x_batch = x_batch.to(device)
    K_batch = K_batch.to(device)
    Qt_batch = Qt_batch.to(device)
    Rt_batch = Rt_batch.to(device)
    At_batch = At_batch.to(device)
    Bt_batch = Bt_batch.to(device)

    loss = 0.0
    for _ in range(time_horizon):
        u_batch = torch.clamp(K @ x_batch, min=-u_max, max=u_max)
        state_cost = torch.bmm(torch.bmm(Qt_batch, x_batch).transpose(2, 1), x_batch)
        control_cost = torch.bmm(torch.bmm(Rt_batch, u_batch).transpose(2, 1), u_batch)
        cost_batch = (state_cost.squeeze() + control_cost.squeeze())
        loss += cost_batch.sum() / (time_horizon * batch_size)
        
        w = noise * torch.randn(batch_size, n, 1).double()
        w = w.to(device)
        
        x_batch = torch.bmm(At_batch, x_batch) + \
            torch.bmm(Bt_batch, u_batch) + w
            
    return loss

jhat_k_lq_opt = lb_loss(100, 6, torch.from_numpy(K_lq_opt).to(device), seed=0).item()

print("lower bound j_lq_opt", j_lq_opt)
print("monte-carlo for K_lq_opt", jhat_k_lq_opt)
print("we see that the lower bound j_lq_opt is NOT tight, no strong duality here")
# Out:
# lower bound j_lq_opt 10.702688100154873
# monte-carlo for K_lq_opt 13.19278317731057
# we see that the lower bound j_lq_opt is NOT tight, no strong duality here

# %%
# set up policy
x = cp.Parameter((n, 1))
P_sqrt = cp.Parameter((n, n))
q = cp.Parameter(n)

u = cp.Variable((m, 1))
xnext = cp.Variable((n, 1))

vclf_is_quadratic = cp.quad_form(u, R0) + cp.sum_squares(P_sqrt @ xnext) + q @ xnext
constraints = [
    xnext == A @ x + B @ u,
    cp.norm(u, "inf") <= u_max
]
controllyapunov_policy = CvxpyLayer(
    cp.Problem(
        cp.Minimize(vclf_is_quadratic),
        constraints
    ),
    [x, P_sqrt, q],
    [u]
)

def loss_controllyapunovpolicy(time_horizon, batch_size, P_sqrt, q, seed=None):
    ''' Monte-Carlo \hat{J} for control-lyapunov optimization solution: u = argmin'''
    ''' although we don't use the autodiff in cvxpylayers here'''
    ''' we are warm-starting the P parameter here with P_sqrt'''
    if seed is not None:
        torch.manual_seed(seed)
    x_batch = noise * torch.randn(batch_size, n, 1).double()
    P_sqrt_batch = P_sqrt.repeat(batch_size, 1, 1)
    q_batch = q.repeat(batch_size, 1)
    Qt_batch = Qt.repeat(batch_size, 1, 1)
    Rt_batch = Rt.repeat(batch_size, 1, 1)
    At_batch = At.repeat(batch_size, 1, 1)
    Bt_batch = Bt.repeat(batch_size, 1, 1)
    
    x_batch = x_batch.to(device)
    P_sqrt_batch = P_sqrt_batch.to(device)
    q_batch = q_batch.to(device)
    Qt_batch = Qt_batch.to(device)
    Rt_batch = Rt_batch.to(device)
    At_batch = At_batch.to(device)
    Bt_batch = Bt_batch.to(device)
    
    loss = 0.0
    for _ in range(time_horizon):
        u_batch, = controllyapunov_policy(
            x_batch,
            P_sqrt_batch,
            q_batch,
            solver_args={"acceleration_lookback": 0, "eps":1e-8, "max_iters":10000})
        
        state_cost = torch.bmm(torch.bmm(Qt_batch, x_batch).transpose(2, 1), x_batch)
        control_cost = torch.bmm(torch.bmm(Rt_batch, u_batch).transpose(2, 1), u_batch)
        cost_batch = (state_cost.squeeze() + control_cost.squeeze())
        loss += cost_batch.sum() / (time_horizon * batch_size)
        
        w = noise * torch.randn(batch_size, n, 1).double()
        w = w.to(device)

        x_batch = torch.bmm(At_batch, x_batch) + \
            torch.bmm(Bt_batch, u_batch) + w
    return loss

with torch.no_grad():
    clf_warmstart_unconstrained = loss_controllyapunovpolicy(100, 6,
        torch.from_numpy(sqrtm(P_unconstrained_opt)),
        torch.zeros(n, dtype=torch.double),
        seed=0).item()
    clf_warmstart_p_lq_opt = loss_controllyapunovpolicy(100, 6,
        torch.from_numpy(sqrtm(P_lq_opt)),
        torch.zeros(n, dtype=torch.double),
        seed=0).item()
print("clf_warmstart_unconstrained", clf_warmstart_unconstrained)

print("lower bound j_lq_opt", j_lq_opt)
print("monte-carlo for K_lq_opt, jhat_k_lq_opt", jhat_k_lq_opt)
print("clf_p_lq_opt", clf_warmstart_p_lq_opt)
print("we see that the lower bound j_lq_opt < clf_warmstart_p_lq_opt < jhat_k_lq_opt < clf_warmstart_unconstrained")
# Out:
# /usr/local/home/cyan3/miniforge/envs/tf/lib/python3.9/site-packages/diffcp/cone_program.py:296: UserWarning: Solved/Inaccurate.
#   warnings.warn("Solved/Inaccurate.")
# clf_warmstart_unconstrained 16.92929399605388
# lower bound j_lq_opt 10.702688100154873
# monte-carlo for K_lq_opt, jhat_k_lq_opt 13.19278317731057
# clf_p_lq_opt 12.887725560706565
# we see that the lower bound j_lq_opt < clf_warmstart_p_lq_opt < jhat_k_lq_opt < clf_warmstart_unconstrained

# %%
# initialize parameters
def train(seed_start, P_sqrt, q):
#     torch.manual_seed(0)
#     P_sqrt = torch.from_numpy(sqrtm(P_lb)); P_sqrt.requires_grad_(True);
#     P_sqrt = torch.eye(n).double(); P_sqrt.requires_grad_(True);

#     q = torch.zeros(n).double(); q.requires_grad_(True);
    # q = torch.ones(n).double(); q.requires_grad_(True);
#     print("seed_start", seed_start)

    opt = torch.optim.SGD([P_sqrt, q], lr=.1)
    losses = []
    for k in range(60):
        with torch.no_grad():
            test_loss = loss_controllyapunovpolicy(100, 6, P_sqrt.detach(), q.detach(), seed=seed_start).item()
            losses.append(test_loss)
#             P_np = (P_sqrt.t() @ P_sqrt).detach().numpy()
#             dist = np.linalg.norm(P_np - P_lb)
            print("it: %03d, loss: %3.3f" % (k+1, test_loss))
        opt.zero_grad()
        l = loss_controllyapunovpolicy(100, 6, P_sqrt, q, seed=k+1)
        l.backward()
        opt.step()
        if k == 30:
            opt = torch.optim.SGD([P_sqrt, q], lr=.01)
            
    return losses

data = {}
s = 5
for i in np.linspace(-s, s, 2*s+1):
    print(i)
    
    P_lq_opt_tensor = i*torch.eye(n);
    q = i*torch.ones(n).double(); 
    
    P_lq_opt_tensor = P_lq_opt_tensor.to(device)
    q = q.to(device)
    
    P_lq_opt_tensor.requires_grad_(True);
    q.requires_grad_(True);
    
    losses2 = train(0, P_lq_opt_tensor, q)

    data[i] = {
        "losses" : losses2,
    }
    
P_lq_opt_tensor = torch.from_numpy(sqrtm(P_lq_opt))
P_lq_opt_tensor = P_lq_opt_tensor.to(device)
P_lq_opt_tensor.requires_grad_(True);
q = torch.ones(n).double(); q = q.to(device); q.requires_grad_(True);
losses1 = train(0, P_lq_opt_tensor, q)
# Out:
# -5.0
# it: 001, loss: 14.337
# it: 002, loss: 13.789
# it: 003, loss: 13.162
# it: 004, loss: 12.605
# it: 005, loss: 12.216
# it: 006, loss: 11.947
# it: 007, loss: 11.811
# it: 008, loss: 11.577
# it: 009, loss: 11.428
# it: 010, loss: 11.394
# it: 011, loss: 11.438
# it: 012, loss: 11.409
# it: 013, loss: 11.471
# it: 014, loss: 11.564
# it: 015, loss: 11.621
# it: 016, loss: 11.694
# it: 017, loss: 11.973
# it: 018, loss: 12.398
# it: 019, loss: 12.582
# it: 020, loss: 12.823
# it: 021, loss: 12.972
# it: 022, loss: 13.037
# it: 023, loss: 13.321
# it: 024, loss: 13.346
# it: 025, loss: 13.398
# it: 026, loss: 13.441
# it: 027, loss: 13.487
# it: 028, loss: 13.509
# it: 029, loss: 13.536
# it: 030, loss: 13.567
# it: 031, loss: 13.716
# it: 032, loss: 13.686
# it: 033, loss: 13.685
# it: 034, loss: 13.686
# it: 035, loss: 13.686
# it: 036, loss: 13.692
# it: 037, loss: 13.690
# it: 038, loss: 13.688
# it: 039, loss: 13.689
# it: 040, loss: 13.690
# it: 041, loss: 13.690
# it: 042, loss: 13.687
# it: 043, loss: 13.687
# it: 044, loss: 13.686
# it: 045, loss: 13.686
# it: 046, loss: 13.686
# it: 047, loss: 13.686
# it: 048, loss: 13.687
# it: 049, loss: 13.686
# it: 050, loss: 13.690
# it: 051, loss: 13.685
# it: 052, loss: 13.686
# it: 053, loss: 13.686
# it: 054, loss: 13.686
# it: 055, loss: 13.685
# it: 056, loss: 13.684
# it: 057, loss: 13.681
# it: 058, loss: 13.680
# it: 059, loss: 13.679
# it: 060, loss: 13.683
# -4.0
# it: 001, loss: 16.470
# it: 002, loss: 14.866
# it: 003, loss: 13.949
# it: 004, loss: 13.206
# it: 005, loss: 12.896
# it: 006, loss: 12.928
# it: 007, loss: 12.916
# it: 008, loss: 12.950
# it: 009, loss: 13.224
# it: 010, loss: 13.308
# it: 011, loss: 13.417
# it: 012, loss: 13.471
# it: 013, loss: 13.520
# it: 014, loss: 13.558
# it: 015, loss: 13.583
# it: 016, loss: 13.587
# it: 017, loss: 13.587
# it: 018, loss: 13.621
# it: 019, loss: 13.601
# it: 020, loss: 13.636
# it: 021, loss: 13.606
# it: 022, loss: 13.608
# it: 023, loss: 13.635
# it: 024, loss: 13.607
# it: 025, loss: 13.607
# it: 026, loss: 13.604
# it: 027, loss: 13.596
# it: 028, loss: 13.571
# it: 029, loss: 13.568
# it: 030, loss: 13.547
# it: 031, loss: 13.595
# it: 032, loss: 13.578
# it: 033, loss: 13.577
# it: 034, loss: 13.579
# it: 035, loss: 13.578
# it: 036, loss: 13.580
# it: 037, loss: 13.577
# it: 038, loss: 13.576
# it: 039, loss: 13.577
# it: 040, loss: 13.577
# it: 041, loss: 13.573
# it: 042, loss: 13.568
# it: 043, loss: 13.567
# it: 044, loss: 13.567
# it: 045, loss: 13.567
# it: 046, loss: 13.564
# it: 047, loss: 13.560
# it: 048, loss: 13.560
# it: 049, loss: 13.558
# it: 050, loss: 13.557
# it: 051, loss: 13.557
# it: 052, loss: 13.553
# it: 053, loss: 13.551
# it: 054, loss: 13.550
# it: 055, loss: 13.549
# it: 056, loss: 13.548
# it: 057, loss: 13.547
# it: 058, loss: 13.543
# it: 059, loss: 13.544
# it: 060, loss: 13.543
# -3.0
# it: 001, loss: 17.775
# it: 002, loss: 14.445
# it: 003, loss: 14.102
# it: 004, loss: 14.019
# it: 005, loss: 13.877
# it: 006, loss: 13.784
# it: 007, loss: 13.750
# it: 008, loss: 13.652
# it: 009, loss: 13.490
# it: 010, loss: 13.528
# it: 011, loss: 13.434
# it: 012, loss: 13.412
# it: 013, loss: 13.382
# it: 014, loss: 13.386
# it: 015, loss: 13.384
# it: 016, loss: 13.379
# it: 017, loss: 13.369
# it: 018, loss: 13.336
# it: 019, loss: 13.320
# it: 020, loss: 13.308
# it: 021, loss: 13.295
# it: 022, loss: 13.301
# it: 023, loss: 13.297
# it: 024, loss: 13.275
# it: 025, loss: 13.270
# it: 026, loss: 13.265
# it: 027, loss: 13.257
# it: 028, loss: 13.250
# it: 029, loss: 13.255
# it: 030, loss: 13.242
# it: 031, loss: 13.265
# it: 032, loss: 13.268
# it: 033, loss: 13.267
# it: 034, loss: 13.267
# it: 035, loss: 13.266
# it: 036, loss: 13.264
# it: 037, loss: 13.263
# it: 038, loss: 13.261
# it: 039, loss: 13.259
# it: 040, loss: 13.256
# it: 041, loss: 13.255
# it: 042, loss: 13.251
# it: 043, loss: 13.250
# it: 044, loss: 13.249
# it: 045, loss: 13.249
# it: 046, loss: 13.246
# it: 047, loss: 13.246
# it: 048, loss: 13.244
# it: 049, loss: 13.244
# it: 050, loss: 13.245
# it: 051, loss: 13.246
# it: 052, loss: 13.244
# it: 053, loss: 13.243
# it: 054, loss: 13.243
# it: 055, loss: 13.242
# it: 056, loss: 13.241
# it: 057, loss: 13.241
# it: 058, loss: 13.239
# it: 059, loss: 13.240
# it: 060, loss: 13.240
# -2.0
# it: 001, loss: 18.086
# it: 002, loss: 14.064
# it: 003, loss: 13.708
# it: 004, loss: 13.477
# it: 005, loss: 13.422
# it: 006, loss: 13.601
# it: 007, loss: 13.373
# it: 008, loss: 13.285
# it: 009, loss: 13.253
# it: 010, loss: 13.209
# it: 011, loss: 13.546
# it: 012, loss: 13.292
# it: 013, loss: 13.231
# it: 014, loss: 13.178
# it: 015, loss: 13.152
# it: 016, loss: 13.174
# it: 017, loss: 13.204
# it: 018, loss: 13.152
# it: 019, loss: 13.096
# it: 020, loss: 13.143
# it: 021, loss: 13.160
# it: 022, loss: 13.142
# it: 023, loss: 13.166
# it: 024, loss: 13.061
# it: 025, loss: 13.106
# it: 026, loss: 13.069
# it: 027, loss: 13.106
# it: 028, loss: 13.115
# it: 029, loss: 13.084
# it: 030, loss: 13.088
# it: 031, loss: 13.106
# it: 032, loss: 13.155
# it: 033, loss: 13.152
# it: 034, loss: 13.171
# it: 035, loss: 13.162
# it: 036, loss: 13.147
# it: 037, loss: 13.142
# it: 038, loss: 13.131
# it: 039, loss: 13.124
# it: 040, loss: 13.117
# it: 041, loss: 13.105
# it: 042, loss: 13.106
# it: 043, loss: 13.105
# it: 044, loss: 13.095
# it: 045, loss: 13.097
# it: 046, loss: 13.094
# it: 047, loss: 13.095
# it: 048, loss: 13.091
# it: 049, loss: 13.089
# it: 050, loss: 13.096
# it: 051, loss: 13.097
# it: 052, loss: 13.092
# it: 053, loss: 13.090
# it: 054, loss: 13.088
# it: 055, loss: 13.085
# it: 056, loss: 13.083
# it: 057, loss: 13.083
# it: 058, loss: 13.078
# it: 059, loss: 13.085
# it: 060, loss: 13.085
# -1.0
# it: 001, loss: 18.305
# it: 002, loss: 17.363
# it: 003, loss: 14.249
# it: 004, loss: 13.721
# it: 005, loss: 13.430
# it: 006, loss: 13.348
# it: 007, loss: 13.257
# it: 008, loss: 13.226
# it: 009, loss: 13.186
# it: 010, loss: 13.155
# it: 011, loss: 13.294
# it: 012, loss: 13.383
# it: 013, loss: 13.392
# it: 014, loss: 13.345
# it: 015, loss: 13.233
# it: 016, loss: 13.243
# it: 017, loss: 13.236
# it: 018, loss: 13.224
# it: 019, loss: 13.260
# it: 020, loss: 13.351
# it: 021, loss: 13.196
# it: 022, loss: 13.204
# it: 023, loss: 13.242
# it: 024, loss: 13.096
# it: 025, loss: 13.095
# it: 026, loss: 12.987
# it: 027, loss: 13.045
# it: 028, loss: 13.059
# it: 029, loss: 13.062
# it: 030, loss: 13.079
# it: 031, loss: 13.366
# it: 032, loss: 13.297
# it: 033, loss: 13.286
# it: 034, loss: 13.311
# it: 035, loss: 13.290
# it: 036, loss: 13.282
# it: 037, loss: 13.267
# it: 038, loss: 13.244
# it: 039, loss: 13.229
# it: 040, loss: 13.233
# it: 041, loss: 13.206
# it: 042, loss: 13.195
# it: 043, loss: 13.190
# it: 044, loss: 13.179
# it: 045, loss: 13.176
# it: 046, loss: 13.172
# it: 047, loss: 13.172
# it: 048, loss: 13.165
# it: 049, loss: 13.164
# it: 050, loss: 13.166
# it: 051, loss: 13.169
# it: 052, loss: 13.156
# it: 053, loss: 13.149
# it: 054, loss: 13.145
# it: 055, loss: 13.135
# it: 056, loss: 13.132
# it: 057, loss: 13.134
# it: 058, loss: 13.133
# it: 059, loss: 13.150
# it: 060, loss: 13.153
# 0.0
# it: 001, loss: 56.325
# it: 002, loss: 56.699
# it: 003, loss: 56.699
# it: 004, loss: 56.699
# it: 005, loss: 56.699
# it: 006, loss: 56.699
# it: 007, loss: 56.699
# it: 008, loss: 56.699
# it: 009, loss: 56.699
# it: 010, loss: 56.699
# it: 011, loss: 56.699
# it: 012, loss: 56.699
# it: 013, loss: 56.699
# it: 014, loss: 56.699
# it: 015, loss: 56.699
# it: 016, loss: 56.699
# it: 017, loss: 56.699
# it: 018, loss: 56.699
# it: 019, loss: 56.699
# it: 020, loss: 56.699
# it: 021, loss: 56.699
# it: 022, loss: 56.699
# it: 023, loss: 56.699
# it: 024, loss: 56.699
# it: 025, loss: 56.699
# it: 026, loss: 56.699
# it: 027, loss: 56.699
# it: 028, loss: 56.699
# it: 029, loss: 56.699
# it: 030, loss: 56.699
# it: 031, loss: 56.699
# it: 032, loss: 56.699
# it: 033, loss: 56.699
# it: 034, loss: 56.699
# it: 035, loss: 56.699
# it: 036, loss: 56.699
# it: 037, loss: 56.699
# it: 038, loss: 56.699
# it: 039, loss: 56.699
# it: 040, loss: 56.699
# it: 041, loss: 56.699
# it: 042, loss: 56.699
# it: 043, loss: 56.699
# it: 044, loss: 56.699
# it: 045, loss: 56.699
# it: 046, loss: 56.699
# it: 047, loss: 56.699
# it: 048, loss: 56.699
# it: 049, loss: 56.699
# it: 050, loss: 56.699
# it: 051, loss: 56.699
# it: 052, loss: 56.699
# it: 053, loss: 56.699
# it: 054, loss: 56.699
# it: 055, loss: 56.699
# it: 056, loss: 56.699
# it: 057, loss: 56.699
# it: 058, loss: 56.699
# it: 059, loss: 56.699
# it: 060, loss: 56.699
# 1.0
# it: 001, loss: 18.168
# it: 002, loss: 17.038
# it: 003, loss: 14.029
# it: 004, loss: 14.005
# it: 005, loss: 13.566
# it: 006, loss: 13.521
# it: 007, loss: 13.472
# it: 008, loss: 13.502
# it: 009, loss: 13.402
# it: 010, loss: 13.357
# it: 011, loss: 13.449
# it: 012, loss: 13.491
# it: 013, loss: 13.509
# it: 014, loss: 13.448
# it: 015, loss: 13.489
# it: 016, loss: 13.456
# it: 017, loss: 13.435
# it: 018, loss: 13.439
# it: 019, loss: 13.330
# it: 020, loss: 13.501
# it: 021, loss: 13.309
# it: 022, loss: 13.374
# it: 023, loss: 13.229
# it: 024, loss: 13.165
# it: 025, loss: 13.127
# it: 026, loss: 13.150
# it: 027, loss: 13.136
# it: 028, loss: 13.141
# it: 029, loss: 13.144
# it: 030, loss: 13.196
# it: 031, loss: 13.343
# it: 032, loss: 13.452
# it: 033, loss: 13.443
# it: 034, loss: 13.431
# it: 035, loss: 13.414
# it: 036, loss: 13.413
# it: 037, loss: 13.387
# it: 038, loss: 13.359
# it: 039, loss: 13.361
# it: 040, loss: 13.347
# it: 041, loss: 13.332
# it: 042, loss: 13.334
# it: 043, loss: 13.327
# it: 044, loss: 13.314
# it: 045, loss: 13.314
# it: 046, loss: 13.308
# it: 047, loss: 13.307
# it: 048, loss: 13.295
# it: 049, loss: 13.297
# it: 050, loss: 13.289
# it: 051, loss: 13.304
# it: 052, loss: 13.282
# it: 053, loss: 13.251
# it: 054, loss: 13.253
# it: 055, loss: 13.235
# it: 056, loss: 13.223
# it: 057, loss: 13.217
# it: 058, loss: 13.213
# it: 059, loss: 13.251
# it: 060, loss: 13.246
# 2.0
# it: 001, loss: 18.165
# it: 002, loss: 14.575
# it: 003, loss: 13.813
# it: 004, loss: 13.830
# it: 005, loss: 13.549
# it: 006, loss: 13.561
# it: 007, loss: 13.530
# it: 008, loss: 13.613
# it: 009, loss: 13.432
# it: 010, loss: 13.421
# it: 011, loss: 13.620
# it: 012, loss: 13.483
# it: 013, loss: 13.483
# it: 014, loss: 13.424
# it: 015, loss: 13.478
# it: 016, loss: 13.448
# it: 017, loss: 13.417
# it: 018, loss: 13.435
# it: 019, loss: 13.324
# it: 020, loss: 13.387
# it: 021, loss: 13.366
# it: 022, loss: 13.328
# it: 023, loss: 13.479
# it: 024, loss: 13.255
# it: 025, loss: 13.248
# it: 026, loss: 13.254
# it: 027, loss: 13.228
# it: 028, loss: 13.221
# it: 029, loss: 13.210
# it: 030, loss: 13.196
# it: 031, loss: 13.374
# it: 032, loss: 13.309
# it: 033, loss: 13.306
# it: 034, loss: 13.317
# it: 035, loss: 13.319
# it: 036, loss: 13.316
# it: 037, loss: 13.310
# it: 038, loss: 13.295
# it: 039, loss: 13.287
# it: 040, loss: 13.281
# it: 041, loss: 13.266
# it: 042, loss: 13.259
# it: 043, loss: 13.258
# it: 044, loss: 13.253
# it: 045, loss: 13.254
# it: 046, loss: 13.247
# it: 047, loss: 13.243
# it: 048, loss: 13.240
# it: 049, loss: 13.243
# it: 050, loss: 13.243
# it: 051, loss: 13.246
# it: 052, loss: 13.235
# it: 053, loss: 13.226
# it: 054, loss: 13.222
# it: 055, loss: 13.220
# it: 056, loss: 13.218
# it: 057, loss: 13.214
# it: 058, loss: 13.205
# it: 059, loss: 13.211
# it: 060, loss: 13.212
# 3.0
# it: 001, loss: 17.776
# it: 002, loss: 14.758
# it: 003, loss: 14.297
# it: 004, loss: 14.106
# it: 005, loss: 13.997
# it: 006, loss: 13.871
# it: 007, loss: 13.888
# it: 008, loss: 13.795
# it: 009, loss: 13.580
# it: 010, loss: 13.610
# it: 011, loss: 13.498
# it: 012, loss: 13.502
# it: 013, loss: 13.482
# it: 014, loss: 13.483
# it: 015, loss: 13.489
# it: 016, loss: 13.487
# it: 017, loss: 13.484
# it: 018, loss: 13.450
# it: 019, loss: 13.432
# it: 020, loss: 13.433
# it: 021, loss: 13.429
# it: 022, loss: 13.422
# it: 023, loss: 13.406
# it: 024, loss: 13.389
# it: 025, loss: 13.387
# it: 026, loss: 13.377
# it: 027, loss: 13.366
# it: 028, loss: 13.358
# it: 029, loss: 13.361
# it: 030, loss: 13.349
# it: 031, loss: 13.353
# it: 032, loss: 13.357
# it: 033, loss: 13.356
# it: 034, loss: 13.358
# it: 035, loss: 13.357
# it: 036, loss: 13.355
# it: 037, loss: 13.353
# it: 038, loss: 13.350
# it: 039, loss: 13.349
# it: 040, loss: 13.348
# it: 041, loss: 13.347
# it: 042, loss: 13.345
# it: 043, loss: 13.345
# it: 044, loss: 13.344
# it: 045, loss: 13.343
# it: 046, loss: 13.342
# it: 047, loss: 13.341
# it: 048, loss: 13.341
# it: 049, loss: 13.340
# it: 050, loss: 13.339
# it: 051, loss: 13.340
# it: 052, loss: 13.338
# it: 053, loss: 13.337
# it: 054, loss: 13.338
# it: 055, loss: 13.337
# it: 056, loss: 13.336
# it: 057, loss: 13.336
# it: 058, loss: 13.335
# it: 059, loss: 13.336
# it: 060, loss: 13.336
# 4.0
# it: 001, loss: 16.327
# it: 002, loss: 14.965
# it: 003, loss: 14.094
# it: 004, loss: 13.186
# it: 005, loss: 12.836
# it: 006, loss: 12.838
# it: 007, loss: 12.874
# it: 008, loss: 12.966
# it: 009, loss: 13.256
# it: 010, loss: 13.326
# it: 011, loss: 13.578
# it: 012, loss: 13.614
# it: 013, loss: 13.622
# it: 014, loss: 13.613
# it: 015, loss: 13.639
# it: 016, loss: 13.638
# it: 017, loss: 13.625
# it: 018, loss: 13.632
# it: 019, loss: 13.612
# it: 020, loss: 13.674
# it: 021, loss: 13.650
# it: 022, loss: 13.649
# it: 023, loss: 13.646
# it: 024, loss: 13.622
# it: 025, loss: 13.619
# it: 026, loss: 13.603
# it: 027, loss: 13.584
# it: 028, loss: 13.568
# it: 029, loss: 13.555
# it: 030, loss: 13.511
# it: 031, loss: 13.539
# it: 032, loss: 13.564
# it: 033, loss: 13.564
# it: 034, loss: 13.566
# it: 035, loss: 13.566
# it: 036, loss: 13.567
# it: 037, loss: 13.565
# it: 038, loss: 13.560
# it: 039, loss: 13.561
# it: 040, loss: 13.560
# it: 041, loss: 13.559
# it: 042, loss: 13.556
# it: 043, loss: 13.555
# it: 044, loss: 13.554
# it: 045, loss: 13.554
# it: 046, loss: 13.552
# it: 047, loss: 13.551
# it: 048, loss: 13.551
# it: 049, loss: 13.550
# it: 050, loss: 13.549
# it: 051, loss: 13.548
# it: 052, loss: 13.547
# it: 053, loss: 13.547
# it: 054, loss: 13.546
# it: 055, loss: 13.545
# it: 056, loss: 13.544
# it: 057, loss: 13.542
# it: 058, loss: 13.540
# it: 059, loss: 13.543
# it: 060, loss: 13.542
# 5.0
# it: 001, loss: 14.204
# it: 002, loss: 13.576
# it: 003, loss: 13.027
# it: 004, loss: 12.531
# it: 005, loss: 12.129
# it: 006, loss: 11.859
# it: 007, loss: 11.694
# it: 008, loss: 11.534
# it: 009, loss: 11.371
# it: 010, loss: 11.327
# it: 011, loss: 11.397
# it: 012, loss: 11.376
# it: 013, loss: 11.514
# it: 014, loss: 11.539
# it: 015, loss: 11.714
# it: 016, loss: 11.779
# it: 017, loss: 11.948
# it: 018, loss: 12.479
# it: 019, loss: 12.732
# it: 020, loss: 13.023
# it: 021, loss: 13.156
# it: 022, loss: 13.217
# it: 023, loss: 13.355
# it: 024, loss: 13.375
# it: 025, loss: 13.435
# it: 026, loss: 13.467
# it: 027, loss: 13.520
# it: 028, loss: 13.525
# it: 029, loss: 13.551
# it: 030, loss: 13.514
# it: 031, loss: 13.688
# it: 032, loss: 13.668
# it: 033, loss: 13.668
# it: 034, loss: 13.670
# it: 035, loss: 13.670
# it: 036, loss: 13.673
# it: 037, loss: 13.672
# it: 038, loss: 13.671
# it: 039, loss: 13.672
# it: 040, loss: 13.673
# it: 041, loss: 13.673
# it: 042, loss: 13.672
# it: 043, loss: 13.665
# it: 044, loss: 13.667
# it: 045, loss: 13.667
# it: 046, loss: 13.668
# it: 047, loss: 13.668
# it: 048, loss: 13.669
# it: 049, loss: 13.668
# it: 050, loss: 13.668
# it: 051, loss: 13.668
# it: 052, loss: 13.670
# it: 053, loss: 13.670
# it: 054, loss: 13.669
# it: 055, loss: 13.669
# it: 056, loss: 13.668
# it: 057, loss: 13.667
# it: 058, loss: 13.666
# it: 059, loss: 13.666
# it: 060, loss: 13.666
# it: 001, loss: 12.902
# it: 002, loss: 12.903
# it: 003, loss: 12.879
# it: 004, loss: 12.987
# it: 005, loss: 12.987
# it: 006, loss: 13.003
# it: 007, loss: 12.972
# it: 008, loss: 12.956
# it: 009, loss: 12.980
# it: 010, loss: 12.948
# it: 011, loss: 13.000
# it: 012, loss: 13.029
# it: 013, loss: 13.027
# it: 014, loss: 13.002
# it: 015, loss: 12.975
# it: 016, loss: 12.946
# it: 017, loss: 12.970
# it: 018, loss: 12.963
# it: 019, loss: 12.960
# it: 020, loss: 13.006
# it: 021, loss: 12.992
# it: 022, loss: 12.984
# it: 023, loss: 13.011
# it: 024, loss: 12.941
# it: 025, loss: 12.959
# it: 026, loss: 12.943
# it: 027, loss: 12.931
# it: 028, loss: 12.936
# it: 029, loss: 12.921
# it: 030, loss: 12.933
# it: 031, loss: 12.905
# it: 032, loss: 12.933
# it: 033, loss: 12.933
# it: 034, loss: 12.938
# it: 035, loss: 12.936
# it: 036, loss: 12.938
# it: 037, loss: 12.933
# it: 038, loss: 12.936
# it: 039, loss: 12.928
# it: 040, loss: 12.927
# it: 041, loss: 12.925
# it: 042, loss: 12.927
# it: 043, loss: 12.927
# it: 044, loss: 12.926
# it: 045, loss: 12.926
# it: 046, loss: 12.931
# it: 047, loss: 12.927
# it: 048, loss: 12.929
# it: 049, loss: 12.928
# it: 050, loss: 12.932
# it: 051, loss: 12.931
# it: 052, loss: 12.930
# it: 053, loss: 12.931
# it: 054, loss: 12.929
# it: 055, loss: 12.929
# it: 056, loss: 12.927
# it: 057, loss: 12.927
# it: 058, loss: 12.927
# it: 059, loss: 12.930
# it: 060, loss: 12.930

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib
from utils import latexify

latexify(fig_width=8)
plt.gca().yaxis.set_minor_formatter(matplotlib.ticker.ScalarFormatter())

print("we see that the lower bound j_lq_opt < clf_warmstart_p_lq_opt < jhat_k_lq_opt < clf_warmstart_unconstrained")
plt.axhline(j_lq_opt, linestyle='--', c='k', label='j_lq_opt')

plt.axhline(jhat_k_lq_opt, linestyle='-.', c='k', label='jhat_k_lq_opt')

plt.axhline(clf_warmstart_p_lq_opt, linestyle='-.', c='g', label='clf_warmstart_p_lq_opt')
plt.axhline(clf_warmstart_unconstrained, linestyle='-.', c='b', label='clf_warmstart_unconstrained')

plt.semilogy(losses1, c='b', label='P_0 = P_lq_opt')

colors = 'rymck'

all_keys = sorted(data.keys())
for s_i, s in enumerate(all_keys):
    plt.semilogy(data[s]["losses"], color=colors[s_i % len(colors)], alpha=0.5)

plt.xlabel('iteration')
plt.ylabel('cost')
plt.subplots_adjust(left=.15, bottom=.2)
plt.ylim(10, 18)
plt.legend(loc='upper right')
plt.savefig("lqr_constrained.jpg")
plt.show()
# Out:
# we see that the lower bound j_lq_opt < clf_warmstart_p_lq_opt < jhat_k_lq_opt < clf_warmstart_unconstrained

# %% [markdown]
# ## Neural net

# %%
from torch import nn
from torch.nn import functional

class Net(nn.Module):
    def __init__(self, n, K):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, m)
        self.fc_K = nn.Linear(n, m, bias=False)
        self.fc_K.weight.data = K.data
#         for fc in [self.fc1, self.fc2, self.fc3]:
#             fc.weight.data.zero_()
#             fc.bias.data.zero_()

    def forward(self, x):
        u = self.fc_K(x) 
        x = functional.relu(self.fc1(x))
        x = functional.relu(self.fc2(x))
        x = torch.clamp(self.fc3(x), -u_max, u_max)
        return x

# %%
policy = Net(n, torch.from_numpy(K_lqr))

# %%
def loss(time_horizon, batch_size, seed=None):
    if seed is not None:
        torch.manual_seed(seed)
    x_batch = noise * torch.randn(batch_size, n, 1).double()
    Qt_batch = Qt.repeat(batch_size, 1, 1)
    Rt_batch = Rt.repeat(batch_size, 1, 1)
    At_batch = At.repeat(batch_size, 1, 1)
    Bt_batch = Bt.repeat(batch_size, 1, 1)
    loss = 0.0
    for _ in range(time_horizon):
        u_batch = policy(x_batch.squeeze(-1))
        u_batch = u_batch.unsqueeze(-1)
        state_cost = torch.bmm(torch.bmm(Qt_batch, x_batch).transpose(2, 1), x_batch)
        control_cost = torch.bmm(torch.bmm(Rt_batch, u_batch).transpose(2, 1), u_batch)
        cost_batch = (state_cost.squeeze() + control_cost.squeeze())
        loss += cost_batch.sum() / (time_horizon * batch_size)
        x_batch = torch.bmm(At_batch, x_batch) + \
            torch.bmm(Bt_batch, u_batch) + \
            noise * torch.randn(batch_size, n, 1).double()
    return loss

# %%
opt = torch.optim.Adam(policy.parameters(), lr=3e-4)
losses = []
for k in range(10000):
    with torch.no_grad():
        test_loss = loss(100, 6, seed=0).item()
        losses.append(test_loss)
        print("it: %03d, loss: %3.3f" % (k+1, test_loss))
    opt.zero_grad()
    l = loss(100, 6, seed=k+1)
    l.backward()
    opt.step()
#     if k == 200:
#         opt = torch.optim.SGD(policy.parameters(), lr=1e-5)
# Out:
# it: 001, loss: 13.605
# it: 002, loss: 13.605
# it: 003, loss: 13.604
# it: 004, loss: 13.596
# it: 005, loss: 13.575
# it: 006, loss: 13.551
# it: 007, loss: 13.527
# it: 008, loss: 13.505
# it: 009, loss: 13.501
# it: 010, loss: 13.491
# it: 011, loss: 13.489
# it: 012, loss: 13.482
# it: 013, loss: 13.471
# it: 014, loss: 13.464
# it: 015, loss: 13.456
# it: 016, loss: 13.448
# it: 017, loss: 13.440
# it: 018, loss: 13.431
# it: 019, loss: 13.415
# it: 020, loss: 13.397
# it: 021, loss: 13.379
# it: 022, loss: 13.360
# it: 023, loss: 13.343
# it: 024, loss: 13.330
# it: 025, loss: 13.321
# it: 026, loss: 13.313
# it: 027, loss: 13.309
# it: 028, loss: 13.304
# it: 029, loss: 13.297
# it: 030, loss: 13.293
# it: 031, loss: 13.289
# it: 032, loss: 13.283
# it: 033, loss: 13.279
# it: 034, loss: 13.275
# it: 035, loss: 13.273
# it: 036, loss: 13.275
# it: 037, loss: 13.276
# it: 038, loss: 13.279
# it: 039, loss: 13.280
# it: 040, loss: 13.280
# it: 041, loss: 13.278
# it: 042, loss: 13.278
# it: 043, loss: 13.277
# it: 044, loss: 13.276
# it: 045, loss: 13.272
# it: 046, loss: 13.267
# it: 047, loss: 13.260
# it: 048, loss: 13.254
# it: 049, loss: 13.250
# it: 050, loss: 13.251
# it: 051, loss: 13.249
# it: 052, loss: 13.247
# it: 053, loss: 13.245
# it: 054, loss: 13.246
# it: 055, loss: 13.247
# it: 056, loss: 13.254
# it: 057, loss: 13.259
# it: 058, loss: 13.264
# it: 059, loss: 13.269
# it: 060, loss: 13.275
# it: 061, loss: 13.279
# it: 062, loss: 13.282
# it: 063, loss: 13.284
# it: 064, loss: 13.285
# it: 065, loss: 13.286
# it: 066, loss: 13.287
# it: 067, loss: 13.285
# it: 068, loss: 13.280
# it: 069, loss: 13.274
# it: 070, loss: 13.267
# it: 071, loss: 13.257
# it: 072, loss: 13.244
# it: 073, loss: 13.236
# it: 074, loss: 13.232
# it: 075, loss: 13.227
# it: 076, loss: 13.218
# it: 077, loss: 13.214
# it: 078, loss: 13.210
# it: 079, loss: 13.202
# it: 080, loss: 13.197
# it: 081, loss: 13.189
# it: 082, loss: 13.186
# it: 083, loss: 13.179
# it: 084, loss: 13.173
# it: 085, loss: 13.169
# it: 086, loss: 13.166
# it: 087, loss: 13.169
# it: 088, loss: 13.171
# it: 089, loss: 13.172
# it: 090, loss: 13.168
# it: 091, loss: 13.165
# it: 092, loss: 13.165
# it: 093, loss: 13.169
# it: 094, loss: 13.174
# it: 095, loss: 13.178
# it: 096, loss: 13.182
# it: 097, loss: 13.186
# it: 098, loss: 13.187
# it: 099, loss: 13.188
# it: 100, loss: 13.193
# it: 101, loss: 13.197
# it: 102, loss: 13.197
# it: 103, loss: 13.199
# it: 104, loss: 13.201
# it: 105, loss: 13.196
# it: 106, loss: 13.190
# it: 107, loss: 13.183
# it: 108, loss: 13.180
# it: 109, loss: 13.185
# it: 110, loss: 13.189
# it: 111, loss: 13.195
# it: 112, loss: 13.210
# it: 113, loss: 13.230
# it: 114, loss: 13.245
# it: 115, loss: 13.252
# it: 116, loss: 13.250
# it: 117, loss: 13.248
# it: 118, loss: 13.244
# it: 119, loss: 13.241
# it: 120, loss: 13.237
# it: 121, loss: 13.230
# it: 122, loss: 13.226
# it: 123, loss: 13.223
# it: 124, loss: 13.220
# it: 125, loss: 13.231
# it: 126, loss: 13.242
# it: 127, loss: 13.251
# it: 128, loss: 13.259
# it: 129, loss: 13.262
# it: 130, loss: 13.260
# it: 131, loss: 13.252
# it: 132, loss: 13.239
# it: 133, loss: 13.227
# it: 134, loss: 13.214
# it: 135, loss: 13.206
# it: 136, loss: 13.199
# it: 137, loss: 13.197
# it: 138, loss: 13.195
# it: 139, loss: 13.197
# it: 140, loss: 13.198
# it: 141, loss: 13.199
# it: 142, loss: 13.198
# it: 143, loss: 13.197
# it: 144, loss: 13.199
# it: 145, loss: 13.205
# it: 146, loss: 13.206
# it: 147, loss: 13.204
# it: 148, loss: 13.203
# it: 149, loss: 13.197
# it: 150, loss: 13.192
# it: 151, loss: 13.182
# it: 152, loss: 13.174
# it: 153, loss: 13.166
# it: 154, loss: 13.167
# it: 155, loss: 13.167
# it: 156, loss: 13.167
# it: 157, loss: 13.169
# it: 158, loss: 13.173
# it: 159, loss: 13.175
# it: 160, loss: 13.176
# it: 161, loss: 13.185
# it: 162, loss: 13.192
# it: 163, loss: 13.196
# it: 164, loss: 13.202
# it: 165, loss: 13.206
# it: 166, loss: 13.209
# it: 167, loss: 13.209
# it: 168, loss: 13.207
# it: 169, loss: 13.200
# it: 170, loss: 13.188
# it: 171, loss: 13.174
# it: 172, loss: 13.161
# it: 173, loss: 13.154
# it: 174, loss: 13.151
# it: 175, loss: 13.146
# it: 176, loss: 13.143
# it: 177, loss: 13.141
# it: 178, loss: 13.135
# it: 179, loss: 13.127
# it: 180, loss: 13.123
# it: 181, loss: 13.122
# it: 182, loss: 13.123
# it: 183, loss: 13.123
# it: 184, loss: 13.126
# it: 185, loss: 13.131
# it: 186, loss: 13.136
# it: 187, loss: 13.141
# it: 188, loss: 13.151
# it: 189, loss: 13.158
# it: 190, loss: 13.163
# it: 191, loss: 13.166
# it: 192, loss: 13.165
# it: 193, loss: 13.164
# it: 194, loss: 13.164
# it: 195, loss: 13.165
# it: 196, loss: 13.166
# it: 197, loss: 13.165
# it: 198, loss: 13.161
# it: 199, loss: 13.156
# it: 200, loss: 13.151
# it: 201, loss: 13.148
# it: 202, loss: 13.145
# it: 203, loss: 13.143
# it: 204, loss: 13.142
# it: 205, loss: 13.141
# it: 206, loss: 13.141
# it: 207, loss: 13.142
# it: 208, loss: 13.144
# it: 209, loss: 13.145
# it: 210, loss: 13.148
# it: 211, loss: 13.150
# it: 212, loss: 13.153
# it: 213, loss: 13.153
# it: 214, loss: 13.154
# it: 215, loss: 13.154
# it: 216, loss: 13.156
# it: 217, loss: 13.158
# it: 218, loss: 13.163
# it: 219, loss: 13.167
# it: 220, loss: 13.173
# it: 221, loss: 13.178
# it: 222, loss: 13.178
# it: 223, loss: 13.178
# it: 224, loss: 13.177
# it: 225, loss: 13.181
# it: 226, loss: 13.180
# it: 227, loss: 13.179
# it: 228, loss: 13.176
# it: 229, loss: 13.174
# it: 230, loss: 13.171
# it: 231, loss: 13.172
# it: 232, loss: 13.172
# it: 233, loss: 13.176
# it: 234, loss: 13.179
# it: 235, loss: 13.179
# it: 236, loss: 13.183
# it: 237, loss: 13.185
# it: 238, loss: 13.188
# it: 239, loss: 13.191
# it: 240, loss: 13.195
# it: 241, loss: 13.196
# it: 242, loss: 13.192
# it: 243, loss: 13.191
# it: 244, loss: 13.191
# it: 245, loss: 13.197
# it: 246, loss: 13.199
# it: 247, loss: 13.197
# it: 248, loss: 13.193
# it: 249, loss: 13.188
# it: 250, loss: 13.180
# it: 251, loss: 13.173
# it: 252, loss: 13.167
# it: 253, loss: 13.165
# it: 254, loss: 13.163
# it: 255, loss: 13.162
# it: 256, loss: 13.161
# it: 257, loss: 13.159
# it: 258, loss: 13.159
# it: 259, loss: 13.160
# it: 260, loss: 13.164
# it: 261, loss: 13.168
# it: 262, loss: 13.176
# it: 263, loss: 13.188
# it: 264, loss: 13.200
# it: 265, loss: 13.214
# it: 266, loss: 13.226
# it: 267, loss: 13.235
# it: 268, loss: 13.241
# it: 269, loss: 13.242
# it: 270, loss: 13.244
# it: 271, loss: 13.247
# it: 272, loss: 13.254
# it: 273, loss: 13.260
# it: 274, loss: 13.263
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-6a9e4fb645ff> in <module>
#       8     opt.zero_grad()
#       9     l = loss(100, 6, seed=k+1)
# ---> 10     l.backward()
#      11     opt.step()
#      12 #     if k == 200:
#
# ~/miniconda3/envs/cvxpylayers/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/miniconda3/envs/cvxpylayers/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt.plot(losses)

# %% [markdown]
# ## Piecewise quadratic

# %%
K = 25

# %%
# set up policy
x = cp.Parameter(n)
P_sqrt_cp = [cp.Parameter((n, n), PSD=True) for _ in range(K)]
q_cp = [cp.Parameter(n) for _ in range(K)]
r_cp = [cp.Parameter(1) for _ in range(K)]

u = cp.Variable(m)
xnext = cp.Variable(n)
t = cp.Variable(1)

objective = cp.quad_form(u, R0) + t
constraints = [xnext == A @ x + B @ u, cp.norm(u, "inf") <= u_max]
constraints += [cp.sum_squares(P_sqrt_cp[i] @ xnext) + q_cp[i] @ xnext + r_cp[i] <= t for i in range(K)]
prob = cp.Problem(cp.Minimize(objective), constraints)
policy = CvxpyLayer(prob, [x] + P_sqrt_cp + q_cp + r_cp, [u])

# %%
P_sqrt = [torch.from_numpy(sqrtm(P_lqr) + 1e-3*np.random.randn(n, n)) for _ in range(K)]
for i in range(K):
    P_sqrt[i].requires_grad_(True)
q = [torch.randn(n, requires_grad=True) for _ in range(K)]
r = [torch.zeros(1, requires_grad=True) for _ in range(K)]

# %%
def loss(time_horizon, batch_size, seed=None):
    if seed is not None:
        torch.manual_seed(seed)
    x_batch = noise * torch.randn(batch_size, n).double()
    Qt_batch = Qt.repeat(batch_size, 1, 1)
    Rt_batch = Rt.repeat(batch_size, 1, 1)
    At_batch = At.repeat(batch_size, 1, 1)
    Bt_batch = Bt.repeat(batch_size, 1, 1)
    loss = 0.0
    for _ in range(time_horizon):
        inputs = [x_batch] + P_sqrt + q + r
        u_batch, = policy(*inputs, solver_args={"acceleration_lookback": 0, "eps":1e-5, "max_iters":10000})
        state_cost = torch.bmm(torch.bmm(Qt_batch, x_batch.unsqueeze(-1)).transpose(2, 1), x_batch.unsqueeze(-1))
        control_cost = torch.bmm(torch.bmm(Rt_batch, u_batch.unsqueeze(-1)).transpose(2, 1), u_batch.unsqueeze(-1))
        cost_batch = (state_cost.squeeze() + control_cost.squeeze())
        loss += cost_batch.sum() / (time_horizon * batch_size)
        x_batch = torch.bmm(At_batch, x_batch.unsqueeze(-1)) + \
            torch.bmm(Bt_batch, u_batch.unsqueeze(-1)) + \
            noise * torch.randn(batch_size, n, 1).double()
        x_batch = x_batch.squeeze(-1)
    return loss

# %%
def norm(list_of_pytorch_tensors):
    with torch.no_grad():
        return torch.cat([t.view(-1) for t in list_of_pytorch_tensors]).norm().item()

# %%
params = P_sqrt + q + r
opt = torch.optim.SGD(params, lr=0.1)
losses = []
for k in range(100):
    with torch.no_grad():
        test_loss = loss(100, 6, seed=0).item()
        losses.append(test_loss)
        if params[0].grad is None:
            grad_norm = np.nan
        else:
            grad_norm = norm([p.grad.data for p in params])
        print("it: %03d, loss: %3.3f, grad_norm: %3.3f" % (k+1, test_loss, grad_norm))
    opt.zero_grad()
    l = loss(100, 6, seed=k+1)
    l.backward()
    torch.nn.utils.clip_grad_norm_(params, 10)
    opt.step()
    if k == 50:
        opt = torch.optim.SGD(params, lr=0.005)
# Out:
# it: 001, loss: 13.368, grad_norm: 0.000
# it: 002, loss: 13.218, grad_norm: 2.971
# it: 003, loss: 13.293, grad_norm: 2.776
# it: 004, loss: 13.455, grad_norm: 5.518
# it: 005, loss: 13.715, grad_norm: 3.672
# it: 006, loss: 13.730, grad_norm: 3.191
# it: 007, loss: 13.817, grad_norm: 3.788
# it: 008, loss: 13.735, grad_norm: 4.652
# it: 009, loss: 13.792, grad_norm: 4.192
# it: 010, loss: 13.480, grad_norm: 4.183
# it: 011, loss: 13.299, grad_norm: 6.466
# it: 012, loss: 13.519, grad_norm: 3.917
# it: 013, loss: 13.386, grad_norm: 4.412
# it: 014, loss: 13.521, grad_norm: 2.561
# it: 015, loss: 13.845, grad_norm: 3.820
# it: 016, loss: 13.671, grad_norm: 1.890
# it: 017, loss: 13.580, grad_norm: 2.818
# it: 018, loss: 13.508, grad_norm: 6.822
# it: 019, loss: 13.659, grad_norm: 8.734
# it: 020, loss: 13.598, grad_norm: 3.174
# it: 021, loss: 13.446, grad_norm: 4.614
# it: 022, loss: 13.518, grad_norm: 4.279
# it: 023, loss: 13.473, grad_norm: 5.674
# it: 024, loss: 13.466, grad_norm: 3.205
# it: 025, loss: 13.397, grad_norm: 4.298
# it: 026, loss: 13.527, grad_norm: 3.969
# it: 027, loss: 13.528, grad_norm: 4.837
# it: 028, loss: 13.424, grad_norm: 2.147
# it: 029, loss: 13.414, grad_norm: 3.381
# it: 030, loss: 13.374, grad_norm: 4.972
# it: 031, loss: 13.466, grad_norm: 4.453
# it: 032, loss: 13.887, grad_norm: 4.018
# it: 033, loss: 13.674, grad_norm: 6.750
# it: 034, loss: 13.524, grad_norm: 4.174
# it: 035, loss: 13.533, grad_norm: 3.244
# it: 036, loss: 13.760, grad_norm: 7.816
# it: 037, loss: 13.812, grad_norm: 2.345
# it: 038, loss: 13.576, grad_norm: 6.047
# it: 039, loss: 13.528, grad_norm: 4.764
# it: 040, loss: 13.522, grad_norm: 2.829
# it: 041, loss: 13.400, grad_norm: 2.327
# it: 042, loss: 13.427, grad_norm: 3.172
# it: 043, loss: 13.596, grad_norm: 1.978
# it: 044, loss: 13.360, grad_norm: 3.592
# it: 045, loss: 13.376, grad_norm: 1.863
# it: 046, loss: 13.648, grad_norm: 10.000
# it: 047, loss: 13.634, grad_norm: 2.687
# it: 048, loss: 13.604, grad_norm: 2.535
# it: 049, loss: 13.847, grad_norm: 6.168
# it: 050, loss: 13.795, grad_norm: 3.298
# it: 051, loss: 13.851, grad_norm: 2.573
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-353835ae8f59> in <module>
#      17     opt.step()
#      18     if k == 50:
# ---> 19         opt = torch.optim.SGD(param, lr=0.005)
#
# NameError: name 'param' is not defined
